# %%
import random
from IPython.display import display
import ipywidgets as widgets

btn = widgets.Button(description="🎲 投掷骰子")
out = widgets.Output()

def roll(_):
    with out:
        out.clear_output()
        print("结果:", random.randint(1, 6))

btn.on_click(roll)
display(btn, out)
